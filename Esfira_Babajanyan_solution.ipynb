# %% [markdown]
# # Esfira Babajanyan Service Titan Internship Task

# %%
import pickle
import pandas as pd

invoices = []
with (open("invoices_new.pkl", "rb")) as invoice_file:
    while True:
        try:
            invoices = pickle.load(invoice_file)
        except EOFError:
            break
            
print(str(invoices[1]))
print(len(invoices))
# Out:
# {'id': 389528, 'created_on': '2019-03-19', 'items': [{'item': {'id': 172535, 'name': 'ii_172535', 'unit_price': 105, 'type': 0}, 'quantity': 4}, {'item': {'id': 175208, 'name': 'ii_175208', 'unit_price': 109, 'type': 0}, 'quantity': 7}, {'item': {'id': 139970, 'name': 'ii_139970', 'unit_price': 193, 'type': 2}, 'quantity': 4}, {'item': {'id': 156273, 'name': 'ii_156273', 'unit_price': 129, 'type': 2}, 'quantity': 6}, {'item': {'id': 178512, 'name': 'ii_178512', 'unit_price': 108, 'type': 1}, 'quantity': 7}, {'item': {'id': 191045, 'name': 'ii_191045', 'unit_price': 195, 'type': 1}, 'quantity': 8}, {'item': {'id': 189841, 'name': 'ii_189841', 'unit_price': 171, 'type': 1}, 'quantity': 4}]}
# 100

# %%
class DataExtractor:
    
    def __init__(self, path_invoices, path_expired = None):
        self.path_invoices = path_invoices
        self.path_expired = path_expired
        
    def load_invoices(self):
        invoices = []
        with (open(self.path_invoices, "rb")) as invoice_file:
            while True:
                try:
                    invoices = pickle.load(invoice_file)
                except EOFError:
                    break
        return invoices
    
    def load_expired(self):
        expired_ids = []
        with open(self.path_expired, 'r') as f:
            ids = f.read()
            expired_ids = ids.split(", ")
        return expired_ids
    
    def calculate_invoice(self, invoice):
        total = 0 
        try:
            items = invoice["items"]
        except KeyError:
            print(f"'items' key not found in invoice: {invoice}")
            return
            
        for item in invoice["items"]:
            try:
                quantity = int(item["quantity"])
                unit_price = int(item["item"]["unit_price"])
            except ValueError:
                print("Invalid value")
                continue           
                
            total += quantity * unit_price
            
        return total
                    
    def transform_invoices(self, invoices):
        item_types = {0: "Material", 1: "Equipment", 2: "Service", 3: "Other"}
        expired_ids = self.load_expired()
        all_items = []
        
        for i in invoices:
            total_invoice_price = self.calculate_invoice(i)
            
            if "items" not in i:
                print(f"'items' key not found in invoice: {i}")
                continue
            
            for item in i["items"]:
                new_item = {}
                new_item["invoice_id"] = i["id"]
                new_item["created_on"] = i["created_on"]
                new_item["invoiceitem_id"] = item["item"]["id"]
                new_item["invoiceitem_name"] = item["item"]["name"]
                new_item["type"] = item_types.get(item["item"]["type"], "Other")
                new_item["unit_price"] = item["item"]["unit_price"]
                new_item["total_price"] = item["item"]["unit_price"] * item["quantity"]
                
                try:
                    total_price = float(new_item["total_price"])
                    new_item["percentage_in_invoice"] = (total_price / total_invoice_price) * 100
                except ValueError:
                    print("Invalid total price")
                    continue
                
                new_item["percentage_in_invoice"] = float(new_item["total_price"] / total_invoice_price) * 100
                new_item["is_expired"] = (str(i["id"]) in expired)
                all_items.append(new_item)
        
        return all_items

# %%
invoices_path = "C:\\Users\\Admin\\Downloads\\data\\invoices_new.pkl"
expired_path = "C:\\Users\\Admin\\Downloads\\data\\expired_invoices.txt"
extracted = DataExtractor(invoices_path, expired_path)

# %%
print(extracted)
# Out:
# <__main__.DataExtractor object at 0x000001CEC25AEC40>

# %%
invoices = extracted.load_invoices()

# %%
expired = extracted.load_expired()

# %%
expired
# Out:
# ['305869',
#  '377307',
#  '391273',
#  '385290',
#  '331902',
#  '397723',
#  '343695',
#  '340601',
#  '347510',
#  '325156',
#  '379387',
#  '348894',
#  '322229',
#  '326649',
#  '377960',
#  '325063',
#  '369378',
#  '319405',
#  '383681',
#  '367288',
#  '356552',
#  '394428',
#  '381476',
#  '381457',
#  '349879',
#  '343254',
#  '366751',
#  '330931',
#  '363263',
#  '326452',
#  '379687',
#  '356532',
#  '383235',
#  '313012',
#  '368913',
#  '352442',
#  '315960',
#  '351096',
#  '331193',
#  '392657',
#  '352391',
#  '389528',
#  '338547',
#  '379961',
#  '337140',
#  '323231',
#  '371205',
#  '378746',
#  '307175',
#  '340299']

# %%
transformed_invoices = extracted.transform_invoices(invoices)
# Out:
# Invalid value
# Invalid total price
# 'items' key not found in invoice: {'id': 379961, 'created_on': '2019-05-12'}
# 'items' key not found in invoice: {'id': 379961, 'created_on': '2019-05-12'}
# 'items' key not found in invoice: {'id': 350506, 'created_on': '2019-01-24'}
# 'items' key not found in invoice: {'id': 350506, 'created_on': '2019-01-24'}
# Invalid value
# Invalid total price
# Invalid value
# Invalid total price
# Invalid value
# Invalid total price

# %%
transformed_invoices
# Out:
# [{'invoice_id': '365371O',
#   'created_on': '2019-05-27',
#   'invoiceitem_id': 142446,
#   'invoiceitem_name': 'ii_142446',
#   'type': 'Equipment',
#   'unit_price': 182,
#   'total_price': 1092,
#   'percentage_in_invoice': 86.1198738170347,
#   'is_expired': False},
#  {'invoice_id': '365371O',
#   'created_on': '2019-05-27',
#   'invoiceitem_id': 154019,
#   'invoiceitem_name': 'ii_154019',
#   'type': 'Equipment',
#   'unit_price': 176,
#   'total_price': 176,
#   'percentage_in_invoice': 13.880126182965299,
#   'is_expired': False},
#  {'invoice_id': 389528,
#   'created_on': '2019-03-19',
#   'invoiceitem_id': 172535,
#   'invoiceitem_name': 'ii_172535',
#   'type': 'Material',
#   'unit_price': 105,
#   'total_price': 420,
#   'percentage_in_invoice': 7.331122359923198,
#   'is_expired': True},
#  {'invoice_id': 389528,
#   'created_on': '2019-03-19',
#   'invoiceitem_id': 175208,
#   'invoiceitem_name': 'ii_175208',
#   'type': 'Material',
#   'unit_price': 109,
#   'total_price': 763,
#   'percentage_in_invoice': 13.318205620527143,
#   'is_expired': True},
#  {'invoice_id': 389528,
#   'created_on': '2019-03-19',
#   'invoiceitem_id': 139970,
#   'invoiceitem_name': 'ii_139970',
#   'type': 'Service',
#   'unit_price': 193,
#   'total_price': 772,
#   'percentage_in_invoice': 13.475301099668355,
#   'is_expired': True},
#  {'invoice_id': 389528,
#   'created_on': '2019-03-19',
#   'invoiceitem_id': 156273,
#   'invoiceitem_name': 'ii_156273',
#   'type': 'Service',
#   'unit_price': 129,
#   'total_price': 774,
#   'percentage_in_invoice': 13.510211206144179,
#   'is_expired': True},
#  {'invoice_id': 389528,
#   'created_on': '2019-03-19',
#   'invoiceitem_id': 178512,
#   'invoiceitem_name': 'ii_178512',
#   'type': 'Equipment',
#   'unit_price': 108,
#   'total_price': 756,
#   'percentage_in_invoice': 13.196020247861757,
#   'is_expired': True},
#  {'invoice_id': 389528,
#   'created_on': '2019-03-19',
#   'invoiceitem_id': 191045,
#   'invoiceitem_name': 'ii_191045',
#   'type': 'Equipment',
#   'unit_price': 195,
#   'total_price': 1560,
#   'percentage_in_invoice': 27.229883051143304,
#   'is_expired': True},
#  {'invoice_id': 389528,
#   'created_on': '2019-03-19',
#   'invoiceitem_id': 189841,
#   'invoiceitem_name': 'ii_189841',
#   'type': 'Equipment',
#   'unit_price': 171,
#   'total_price': 684,
#   'percentage_in_invoice': 11.939256414732064,
#   'is_expired': True},
#  {'invoice_id': 341762,
#   'created_on': '2019-06-19',
#   'invoiceitem_id': 143176,
#   'invoiceitem_name': 'ii_143176',
#   'type': 'Service',
#   'unit_price': 175,
#   'total_price': 350,
#   'percentage_in_invoice': 8.962868117797695,
#   'is_expired': False},
#  {'invoice_id': 341762,
#   'created_on': '2019-06-19',
#   'invoiceitem_id': 161765,
#   'invoiceitem_name': 'ii_161765',
#   'type': 'Service',
#   'unit_price': 170,
#   'total_price': 1360,
#   'percentage_in_invoice': 34.82714468629962,
#   'is_expired': False},
#  {'invoice_id': 341762,
#   'created_on': '2019-06-19',
#   'invoiceitem_id': 167763,
#   'invoiceitem_name': 'ii_167763',
#   'type': 'Other',
#   'unit_price': 150,
#   'total_price': 750,
#   'percentage_in_invoice': 19.206145966709347,
#   'is_expired': False},
#  {'invoice_id': 341762,
#   'created_on': '2019-06-19',
#   'invoiceitem_id': 195203,
#   'invoiceitem_name': 'ii_195203',
#   'type': 'Material',
#   'unit_price': 194,
#   'total_price': 582,
#   'percentage_in_invoice': 14.903969270166453,
#   'is_expired': False},
#  {'invoice_id': 341762,
#   'created_on': '2019-06-19',
#   'invoiceitem_id': 188321,
#   'invoiceitem_name': 'ii_188321',
#   'type': 'Other',
#   'unit_price': 101,
#   'total_price': 101,
#   'percentage_in_invoice': 2.586427656850192,
#   'is_expired': False},
#  {'invoice_id': 341762,
#   'created_on': '2019-06-19',
#   'invoiceitem_id': 114990,
#   'invoiceitem_name': 'ii_114990',
#   'type': 'Other',
#   'unit_price': 132,
#   'total_price': 264,
#   'percentage_in_invoice': 6.760563380281689,
#   'is_expired': False},
#  {'invoice_id': 341762,
#   'created_on': '2019-06-19',
#   'invoiceitem_id': 126940,
#   'invoiceitem_name': 'ii_126940',
#   'type': 'Material',
#   'unit_price': 166,
#   'total_price': 498,
#   'percentage_in_invoice': 12.752880921895008,
#   'is_expired': False},
#  {'invoice_id': 319405,
#   'created_on': '2019-03-27',
#   'invoiceitem_id': 141009,
#   'invoiceitem_name': 'ii_141009',
#   'type': 'Material',
#   'unit_price': 161,
#   'total_price': 161,
#   'percentage_in_invoice': 12.050898203592816,
#   'is_expired': True},
#  {'invoice_id': 319405,
#   'created_on': '2019-03-27',
#   'invoiceitem_id': 195216,
#   'invoiceitem_name': 'ii_195216',
#   'type': 'Service',
#   'unit_price': 140,
#   'total_price': 280,
#   'percentage_in_invoice': 20.958083832335326,
#   'is_expired': True},
#  {'invoice_id': 319405,
#   'created_on': '2019-03-27',
#   'invoiceitem_id': 108059,
#   'invoiceitem_name': 'ii_108059',
#   'type': 'Service',
#   'unit_price': 118,
#   'total_price': 708,
#   'percentage_in_invoice': 52.99401197604791,
#   'is_expired': True},
#  {'invoice_id': 319405,
#   'created_on': '2019-03-27',
#   'invoiceitem_id': 171459,
#   'invoiceitem_name': 'ii_171459',
#   'type': 'Other',
#   'unit_price': 187,
#   'total_price': 187,
#   'percentage_in_invoice': 13.997005988023952,
#   'is_expired': True},
#  {'invoice_id': 343695,
#   'created_on': '2019-04-10',
#   'invoiceitem_id': 147038,
#   'invoiceitem_name': 'ii_147038',
#   'type': 'Material',
#   'unit_price': 177,
#   'total_price': 177,
#   'percentage_in_invoice': 100.0,
#   'is_expired': True},
#  {'invoice_id': 358095,
#   'created_on': '2019-03-19',
#   'invoiceitem_id': 147214,
#   'invoiceitem_name': 'ii_147214',
#   'type': 'Material',
#   'unit_price': 117,
#   'total_price': 468,
#   'percentage_in_invoice': 36.61971830985916,
#   'is_expired': False},
#  {'invoice_id': 358095,
#   'created_on': '2019-03-19',
#   'invoiceitem_id': 152191,
#   'invoiceitem_name': 'ii_152191',
#   'type': 'Equipment',
#   'unit_price': 135,
#   'total_price': 810,
#   'percentage_in_invoice': 63.38028169014085,
#   'is_expired': False},
#  {'invoice_id': 381281,
#   'created_on': '2019-05-16',
#   'invoiceitem_id': 191864,
#   'invoiceitem_name': 'ii_191864',
#   'type': 'Service',
#   'unit_price': 176,
#   'total_price': 352,
#   'percentage_in_invoice': 41.509433962264154,
#   'is_expired': False},
#  {'invoice_id': 381281,
#   'created_on': '2019-05-16',
#   'invoiceitem_id': 110832,
#   'invoiceitem_name': 'ii_110832',
#   'type': 'Other',
#   'unit_price': 124,
#   'total_price': 496,
#   'percentage_in_invoice': 58.490566037735846,
#   'is_expired': False},
#  {'invoice_id': 352391,
#   'created_on': '2019-01-18',
#   'invoiceitem_id': 178909,
#   'invoiceitem_name': 'ii_178909',
#   'type': 'Other',
#   'unit_price': 161,
#   'total_price': 161,
#   'percentage_in_invoice': 4.241306638566913,
#   'is_expired': True},
#  {'invoice_id': 352391,
#   'created_on': '2019-01-18',
#   'invoiceitem_id': 104981,
#   'invoiceitem_name': 'ii_104981',
#   'type': 'Other',
#   'unit_price': 141,
#   'total_price': 141,
#   'percentage_in_invoice': 3.7144362486828237,
#   'is_expired': True},
#  {'invoice_id': 352391,
#   'created_on': '2019-01-18',
#   'invoiceitem_id': 167699,
#   'invoiceitem_name': 'ii_167699',
#   'type': 'Other',
#   'unit_price': 144,
#   'total_price': 576,
#   'percentage_in_invoice': 15.17386722866175,
#   'is_expired': True},
#  {'invoice_id': 352391,
#   'created_on': '2019-01-18',
#   'invoiceitem_id': 193687,
#   'invoiceitem_name': 'ii_193687',
#   'type': 'Material',
#   'unit_price': 166,
#   'total_price': 996,
#   'percentage_in_invoice': 26.23814541622761,
#   'is_expired': True},
#  {'invoice_id': 352391,
#   'created_on': '2019-01-18',
#   'invoiceitem_id': 138301,
#   'invoiceitem_name': 'ii_138301',
#   'type': 'Equipment',
#   'unit_price': 128,
#   'total_price': 1024,
#   'percentage_in_invoice': 26.97576396206533,
#   'is_expired': True},
#  {'invoice_id': 352391,
#   'created_on': '2019-01-18',
#   'invoiceitem_id': 179050,
#   'invoiceitem_name': 'ii_179050',
#   'type': 'Other',
#   'unit_price': 162,
#   'total_price': 648,
#   'percentage_in_invoice': 17.070600632244467,
#   'is_expired': True},
#  {'invoice_id': 352391,
#   'created_on': '2019-01-18',
#   'invoiceitem_id': 198345,
#   'invoiceitem_name': 'ii_198345',
#   'type': 'Service',
#   'unit_price': 125,
#   'total_price': 250,
#   'percentage_in_invoice': 6.585879873551106,
#   'is_expired': True},
#  {'invoice_id': '374089O',
#   'created_on': '2019-09-30',
#   'invoiceitem_id': 160942,
#   'invoiceitem_name': 'ii_160942',
#   'type': 'Service',
#   'unit_price': 162,
#   'total_price': 648,
#   'percentage_in_invoice': 28.235294117647058,
#   'is_expired': False},
#  {'invoice_id': '374089O',
#   'created_on': '2019-09-30',
#   'invoiceitem_id': 156315,
#   'invoiceitem_name': 'ii_156315',
#   'type': 'Other',
#   'unit_price': 151,
#   'total_price': 1208,
#   'percentage_in_invoice': 52.636165577342055,
#   'is_expired': False},
#  {'invoice_id': '374089O',
#   'created_on': '2019-09-30',
#   'invoiceitem_id': 128859,
#   'invoiceitem_name': 'ii_128859',
#   'type': 'Equipment',
#   'unit_price': 117,
#   'total_price': 117,
#   'percentage_in_invoice': 5.098039215686274,
#   'is_expired': False},
#  {'invoice_id': '374089O',
#   'created_on': '2019-09-30',
#   'invoiceitem_id': 152319,
#   'invoiceitem_name': 'ii_152319',
#   'type': 'Other',
#   'unit_price': 161,
#   'total_price': 322,
#   'percentage_in_invoice': 14.030501089324618,
#   'is_expired': False},
#  {'invoice_id': 331193,
#   'created_on': '2019-04-12',
#   'invoiceitem_id': 195938,
#   'invoiceitem_name': 'ii_195938',
#   'type': 'Other',
#   'unit_price': 129,
#   'total_price': 258,
#   'percentage_in_invoice': 8.425865447419987,
#   'is_expired': True},
#  {'invoice_id': 331193,
#   'created_on': '2019-04-12',
#   'invoiceitem_id': 160255,
#   'invoiceitem_name': 'ii_160255',
#   'type': 'Service',
#   'unit_price': 169,
#   'total_price': 169,
#   'percentage_in_invoice': 5.519268451992162,
#   'is_expired': True},
#  {'invoice_id': 331193,
#   'created_on': '2019-04-12',
#   'invoiceitem_id': 198688,
#   'invoiceitem_name': 'ii_198688',
#   'type': 'Service',
#   'unit_price': 102,
#   'total_price': 612,
#   'percentage_in_invoice': 19.98693664271718,
#   'is_expired': True},
#  {'invoice_id': 331193,
#   'created_on': '2019-04-12',
#   'invoiceitem_id': 101279,
#   'invoiceitem_name': 'ii_101279',
#   'type': 'Service',
#   'unit_price': 164,
#   'total_price': 328,
#   'percentage_in_invoice': 10.711952971913782,
#   'is_expired': True},
#  {'invoice_id': 331193,
#   'created_on': '2019-04-12',
#   'invoiceitem_id': 105136,
#   'invoiceitem_name': 'ii_105136',
#   'type': 'Equipment',
#   'unit_price': 193,
#   'total_price': 579,
#   'percentage_in_invoice': 18.90920966688439,
#   'is_expired': True},
#  {'invoice_id': 331193,
#   'created_on': '2019-04-12',
#   'invoiceitem_id': 167356,
#   'invoiceitem_name': 'ii_167356',
#   'type': 'Equipment',
#   'unit_price': 118,
#   'total_price': 826,
#   'percentage_in_invoice': 26.975832789026782,
#   'is_expired': True},
#  {'invoice_id': 331193,
#   'created_on': '2019-04-12',
#   'invoiceitem_id': 130940,
#   'invoiceitem_name': 'ii_130940',
#   'type': 'Service',
#   'unit_price': 145,
#   'total_price': 290,
#   'percentage_in_invoice': 9.470934030045722,
#   'is_expired': True},
#  {'invoice_id': 347510,
#   'created_on': '2019-02-10',
#   'invoiceitem_id': 142237,
#   'invoiceitem_name': 'ii_142237',
#   'type': 'Equipment',
#   'unit_price': 167,
#   'total_price': 1336,
#   'percentage_in_invoice': 26.778913609941874,
#   'is_expired': True},
#  {'invoice_id': 347510,
#   'created_on': '2019-02-10',
#   'invoiceitem_id': 106048,
#   'invoiceitem_name': 'ii_106048',
#   'type': 'Equipment',
#   'unit_price': 188,
#   'total_price': 1316,
#   'percentage_in_invoice': 26.37803166967328,
#   'is_expired': True},
#  {'invoice_id': 347510,
#   'created_on': '2019-02-10',
#   'invoiceitem_id': 166330,
#   'invoiceitem_name': 'ii_166330',
#   'type': 'Service',
#   'unit_price': 116,
#   'total_price': 464,
#   'percentage_in_invoice': 9.30046101423131,
#   'is_expired': True},
#  {'invoice_id': 347510,
#   'created_on': '2019-02-10',
#   'invoiceitem_id': 197845,
#   'invoiceitem_name': 'ii_197845',
#   'type': 'Service',
#   'unit_price': 173,
#   'total_price': 865,
#   'percentage_in_invoice': 17.338143916616556,
#   'is_expired': True},
#  {'invoice_id': 347510,
#   'created_on': '2019-02-10',
#   'invoiceitem_id': 133899,
#   'invoiceitem_name': 'ii_133899',
#   'type': 'Other',
#   'unit_price': 144,
#   'total_price': 1008,
#   'percentage_in_invoice': 20.204449789536984,
#   'is_expired': True},
#  {'invoice_id': 307175,
#   'created_on': '2019-05-19',
#   'invoiceitem_id': 134663,
#   'invoiceitem_name': 'ii_134663',
#   'type': 'Material',
#   'unit_price': 175,
#   'total_price': 1400,
#   'percentage_in_invoice': 27.960854803275414,
#   'is_expired': True},
#  {'invoice_id': 307175,
#   'created_on': '2019-05-19',
#   'invoiceitem_id': 136924,
#   'invoiceitem_name': 'ii_136924',
#   'type': 'Material',
#   'unit_price': 183,
#   'total_price': 1464,
#   'percentage_in_invoice': 29.23906530856801,
#   'is_expired': True},
#  {'invoice_id': 307175,
#   'created_on': '2019-05-19',
#   'invoiceitem_id': 122138,
#   'invoiceitem_name': 'ii_122138',
#   'type': 'Material',
#   'unit_price': 195,
#   'total_price': 1560,
#   'percentage_in_invoice': 31.15638106650689,
#   'is_expired': True},
#  {'invoice_id': 307175,
#   'created_on': '2019-05-19',
#   'invoiceitem_id': 133742,
#   'invoiceitem_name': 'ii_133742',
#   'type': 'Equipment',
#   'unit_price': 115,
#   'total_price': 345,
#   'percentage_in_invoice': 6.890353505092869,
#   'is_expired': True},
#  {'invoice_id': 307175,
#   'created_on': '2019-05-19',
#   'invoiceitem_id': 185633,
#   'invoiceitem_name': 'ii_185633',
#   'type': 'Material',
#   'unit_price': 119,
#   'total_price': 238,
#   'percentage_in_invoice': 4.75334531655682,
#   'is_expired': True},
#  {'invoice_id': 369378,
#   'created_on': '2019-07-15',
#   'invoiceitem_id': 137032,
#   'invoiceitem_name': 'ii_137032',
#   'type': 'Other',
#   'unit_price': 116,
#   'total_price': 580,
#   'percentage_in_invoice': 12.747252747252746,
#   'is_expired': True},
#  {'invoice_id': 369378,
#   'created_on': '2019-07-15',
#   'invoiceitem_id': 126483,
#   'invoiceitem_name': 'ii_126483',
#   'type': 'Equipment',
#   'unit_price': 165,
#   'total_price': 1155,
#   'percentage_in_invoice': 25.384615384615383,
#   'is_expired': True},
#  {'invoice_id': 369378,
#   'created_on': '2019-07-15',
#   'invoiceitem_id': 108758,
#   'invoiceitem_name': 'ii_108758',
#   'type': 'Service',
#   'unit_price': 177,
#   'total_price': 708,
#   'percentage_in_invoice': 15.56043956043956,
#   'is_expired': True},
#  {'invoice_id': 369378,
#   'created_on': '2019-07-15',
#   'invoiceitem_id': 183393,
#   'invoiceitem_name': 'ii_183393',
#   'type': 'Equipment',
#   'unit_price': 194,
#   'total_price': 970,
#   'percentage_in_invoice': 21.318681318681318,
#   'is_expired': True},
#  {'invoice_id': 369378,
#   'created_on': '2019-07-15',
#   'invoiceitem_id': 190308,
#   'invoiceitem_name': 'ii_190308',
#   'type': 'Other',
#   'unit_price': 124,
#   'total_price': 248,
#   'percentage_in_invoice': 5.450549450549451,
#   'is_expired': True},
#  {'invoice_id': 369378,
#   'created_on': '2019-07-15',
#   'invoiceitem_id': 177376,
#   'invoiceitem_name': 'ii_177376',
#   'type': 'Other',
#   'unit_price': 127,
#   'total_price': 889,
#   'percentage_in_invoice': 19.538461538461537,
#   'is_expired': True},
#  {'invoice_id': 377307,
#   'created_on': '2019-04-12',
#   'invoiceitem_id': 174987,
#   'invoiceitem_name': 'ii_174987',
#   'type': 'Equipment',
#   'unit_price': 127,
#   'total_price': 508,
#   'percentage_in_invoice': 13.674293405114401,
#   'is_expired': True},
#  {'invoice_id': 377307,
#   'created_on': '2019-04-12',
#   'invoiceitem_id': 151916,
#   'invoiceitem_name': 'ii_151916',
#   'type': 'Material',
#   'unit_price': 117,
#   'total_price': 819,
#   'percentage_in_invoice': 22.045760430686407,
#   'is_expired': True},
#  {'invoice_id': 377307,
#   'created_on': '2019-04-12',
#   'invoiceitem_id': 194584,
#   'invoiceitem_name': 'ii_194584',
#   'type': 'Material',
#   'unit_price': 146,
#   'total_price': 584,
#   'percentage_in_invoice': 15.720053835800806,
#   'is_expired': True},
#  {'invoice_id': 377307,
#   'created_on': '2019-04-12',
#   'invoiceitem_id': 190386,
#   'invoiceitem_name': 'ii_190386',
#   'type': 'Service',
#   'unit_price': 156,
#   'total_price': 1248,
#   'percentage_in_invoice': 33.5935397039031,
#   'is_expired': True},
#  {'invoice_id': 377307,
#   'created_on': '2019-04-12',
#   'invoiceitem_id': 151535,
#   'invoiceitem_name': 'ii_151535',
#   'type': 'Equipment',
#   'unit_price': 139,
#   'total_price': 556,
#   'percentage_in_invoice': 14.966352624495288,
#   'is_expired': True},
#  {'invoice_id': 367288,
#   'created_on': '2019-06-29',
#   'invoiceitem_id': 117929,
#   'invoiceitem_name': 'ii_117929',
#   'type': 'Other',
#   'unit_price': 155,
#   'total_price': 620,
#   'percentage_in_invoice': 22.326251350378108,
#   'is_expired': True},
#  {'invoice_id': 367288,
#   'created_on': '2019-06-29',
#   'invoiceitem_id': 182802,
#   'invoiceitem_name': 'ii_182802',
#   'type': 'Other',
#   'unit_price': 155,
#   'total_price': 465,
#   'percentage_in_invoice': 16.74468851278358,
#   'is_expired': True},
#  {'invoice_id': 367288,
#   'created_on': '2019-06-29',
#   'invoiceitem_id': 104800,
#   'invoiceitem_name': 'ii_104800',
#   'type': 'Service',
#   'unit_price': 103,
#   'total_price': 824,
#   'percentage_in_invoice': 29.672308246308965,
#   'is_expired': True},
#  {'invoice_id': 367288,
#   'created_on': '2019-06-29',
#   'invoiceitem_id': 146906,
#   'invoiceitem_name': 'ii_146906',
#   'type': 'Service',
#   'unit_price': 132,
#   'total_price': 660,
#   'percentage_in_invoice': 23.766654663305726,
#   'is_expired': True},
#  {'invoice_id': 367288,
#   'created_on': '2019-06-29',
#   'invoiceitem_id': 178253,
#   'invoiceitem_name': 'ii_178253',
#   'type': 'Equipment',
#   'unit_price': 104,
#   'total_price': 208,
#   'percentage_in_invoice': 7.490097227223623,
#   'is_expired': True},
#  {'invoice_id': 337140,
#   'created_on': '2019-06-23',
#   'invoiceitem_id': 131446,
#   'invoiceitem_name': 'ii_131446',
#   'type': 'Service',
#   'unit_price': 196,
#   'total_price': 196,
#   'percentage_in_invoice': 10.359408033826638,
#   'is_expired': True},
#  {'invoice_id': 337140,
#   'created_on': '2019-06-23',
#   'invoiceitem_id': 168508,
#   'invoiceitem_name': 'ii_168508',
#   'type': 'Material',
#   'unit_price': 109,
#   'total_price': 436,
#   'percentage_in_invoice': 23.044397463002113,
#   'is_expired': True},
#  {'invoice_id': 337140,
#   'created_on': '2019-06-23',
#   'invoiceitem_id': 171389,
#   'invoiceitem_name': 'ii_171389',
#   'type': 'Material',
#   'unit_price': 183,
#   'total_price': 183,
#   'percentage_in_invoice': 9.6723044397463,
#   'is_expired': True},
#  {'invoice_id': 337140,
#   'created_on': '2019-06-23',
#   'invoiceitem_id': 117794,
#   'invoiceitem_name': 'ii_117794',
#   'type': 'Other',
#   'unit_price': 155,
#   'total_price': 930,
#   'percentage_in_invoice': 49.15433403805497,
#   'is_expired': True},
#  {'invoice_id': 337140,
#   'created_on': '2019-06-23',
#   'invoiceitem_id': 184268,
#   'invoiceitem_name': 'ii_184268',
#   'type': 'Other',
#   'unit_price': 147,
#   'total_price': 147,
#   'percentage_in_invoice': 7.76955602536998,
#   'is_expired': True},
#  {'invoice_id': 315960,
#   'created_on': '2019-09-27',
#   'invoiceitem_id': 117240,
#   'invoiceitem_name': 'ii_117240',
#   'type': 'Other',
#   'unit_price': 139,
#   'total_price': 417,
#   'percentage_in_invoice': 7.958015267175572,
#   'is_expired': True},
#  {'invoice_id': 315960,
#   'created_on': '2019-09-27',
#   'invoiceitem_id': 104513,
#   'invoiceitem_name': 'ii_104513',
#   'type': 'Equipment',
#   'unit_price': 165,
#   'total_price': 1320,
#   'percentage_in_invoice': 25.190839694656486,
#   'is_expired': True},
#  {'invoice_id': 315960,
#   'created_on': '2019-09-27',
#   'invoiceitem_id': 172757,
#   'invoiceitem_name': 'ii_172757',
#   'type': 'Service',
#   'unit_price': 155,
#   'total_price': 310,
#   'percentage_in_invoice': 5.916030534351145,
#   'is_expired': True},
#  {'invoice_id': 315960,
#   'created_on': '2019-09-27',
#   'invoiceitem_id': 103202,
#   'invoiceitem_name': 'ii_103202',
#   'type': 'Equipment',
#   'unit_price': 113,
#   'total_price': 678,
#   'percentage_in_invoice': 12.938931297709924,
#   'is_expired': True},
#  {'invoice_id': 315960,
#   'created_on': '2019-09-27',
#   'invoiceitem_id': 100883,
#   'invoiceitem_name': 'ii_100883',
#   'type': 'Service',
#   'unit_price': 187,
#   'total_price': 1122,
#   'percentage_in_invoice': 21.412213740458018,
#   'is_expired': True},
#  {'invoice_id': 315960,
#   'created_on': '2019-09-27',
#   'invoiceitem_id': 194744,
#   'invoiceitem_name': 'ii_194744',
#   'type': 'Material',
#   'unit_price': 131,
#   'total_price': 917,
#   'percentage_in_invoice': 17.5,
#   'is_expired': True},
#  {'invoice_id': 315960,
#   'created_on': '2019-09-27',
#   'invoiceitem_id': 128573,
#   'invoiceitem_name': 'ii_128573',
#   'type': 'Equipment',
#   'unit_price': 119,
#   'total_price': 476,
#   'percentage_in_invoice': 9.083969465648854,
#   'is_expired': True},
#  {'invoice_id': 340601,
#   'created_on': '2019-08-16',
#   'invoiceitem_id': 144257,
#   'invoiceitem_name': 'ii_144257',
#   'type': 'Material',
#   'unit_price': 148,
#   'total_price': 1036,
#   'percentage_in_invoice': 42.38952536824877,
#   'is_expired': True},
#  {'invoice_id': 340601,
#   'created_on': '2019-08-16',
#   'invoiceitem_id': 116446,
#   'invoiceitem_name': 'ii_116446',
#   'type': 'Service',
#   'unit_price': 129,
#   'total_price': 903,
#   'percentage_in_invoice': 36.94762684124386,
#   'is_expired': True},
#  {'invoice_id': 340601,
#   'created_on': '2019-08-16',
#   'invoiceitem_id': 126267,
#   'invoiceitem_name': 'ii_126267',
#   'type': 'Service',
#   'unit_price': 171,
#   'total_price': 342,
#   'percentage_in_invoice': 13.993453355155482,
#   'is_expired': True},
#  {'invoice_id': 340601,
#   'created_on': '2019-08-16',
#   'invoiceitem_id': 145047,
#   'invoiceitem_name': 'ii_145047',
#   'type': 'Material',
#   'unit_price': 163,
#   'total_price': 163,
#   'percentage_in_invoice': 6.669394435351881,
#   'is_expired': True},
#  {'invoice_id': '397723O',
#   'created_on': '2019-05-11',
#   'invoiceitem_id': 181613,
#   'invoiceitem_name': 'ii_181613',
#   'type': 'Material',
#   'unit_price': 161,
#   'total_price': 483,
#   'percentage_in_invoice': 26.23574144486692,
#   'is_expired': False},
#  {'invoice_id': '397723O',
#   'created_on': '2019-05-11',
#   'invoiceitem_id': 117999,
#   'invoiceitem_name': 'ii_117999',
#   'type': 'Equipment',
#   'unit_price': 196,
#   'total_price': 392,
#   'percentage_in_invoice': 21.292775665399237,
#   'is_expired': False},
#  {'invoice_id': '397723O',
#   'created_on': '2019-05-11',
#   'invoiceitem_id': 198198,
#   'invoiceitem_name': 'ii_198198',
#   'type': 'Material',
#   'unit_price': 122,
#   'total_price': 366,
#   'percentage_in_invoice': 19.880499728408473,
#   'is_expired': False},
#  {'invoice_id': '397723O',
#   'created_on': '2019-05-11',
#   'invoiceitem_id': 121772,
#   'invoiceitem_name': 'ii_121772',
#   'type': 'Material',
#   'unit_price': 120,
#   'total_price': 600,
#   'percentage_in_invoice': 32.59098316132537,
#   'is_expired': False},
#  {'invoice_id': 379687,
#   'created_on': '2019-05-24',
#   'invoiceitem_id': 139615,
#   'invoiceitem_name': 'ii_139615',
#   'type': 'Material',
#   'unit_price': 194,
#   'total_price': 582,
#   'percentage_in_invoice': 11.427449440408404,
#   'is_expired': True},
#  {'invoice_id': 379687,
#   'created_on': '2019-05-24',
#   'invoiceitem_id': 155726,
#   'invoiceitem_name': 'ii_155726',
#   'type': 'Equipment',
#   'unit_price': 149,
#   'total_price': 1043,
#   'percentage_in_invoice': 20.479088945611622,
#   'is_expired': True},
#  {'invoice_id': 379687,
#   'created_on': '2019-05-24',
#   'invoiceitem_id': 188916,
#   'invoiceitem_name': 'ii_188916',
#   'type': 'Service',
#   'unit_price': 165,
#   'total_price': 495,
#   'percentage_in_invoice': 9.719222462203025,
#   'is_expired': True},
#  {'invoice_id': 379687,
#   'created_on': '2019-05-24',
#   'invoiceitem_id': 164157,
#   'invoiceitem_name': 'ii_164157',
#   'type': 'Service',
#   'unit_price': 195,
#   'total_price': 195,
#   'percentage_in_invoice': 3.828784606322403,
#   'is_expired': True},
#  {'invoice_id': 379687,
#   'created_on': '2019-05-24',
#   'invoiceitem_id': 135770,
#   'invoiceitem_name': 'ii_135770',
#   'type': 'Other',
#   'unit_price': 174,
#   'total_price': 522,
#   'percentage_in_invoice': 10.24936186923228,
#   'is_expired': True},
#  {'invoice_id': 379687,
#   'created_on': '2019-05-24',
#   'invoiceitem_id': 107730,
#   'invoiceitem_name': 'ii_107730',
#   'type': 'Equipment',
#   'unit_price': 177,
#   'total_price': 1416,
#   'percentage_in_invoice': 27.802866679756526,
#   'is_expired': True},
#  {'invoice_id': 379687,
#   'created_on': '2019-05-24',
#   'invoiceitem_id': 139278,
#   'invoiceitem_name': 'ii_139278',
#   'type': 'Material',
#   'unit_price': 120,
#   'total_price': 840,
#   'percentage_in_invoice': 16.49322599646574,
#   'is_expired': True},
#  {'invoice_id': 309022,
#   'created_on': '2019-04-18',
#   'invoiceitem_id': 161511,
#   'invoiceitem_name': 'ii_161511',
#   'type': 'Equipment',
#   'unit_price': 102,
#   'total_price': 204,
#   'percentage_in_invoice': 4.992657856093979,
#   'is_expired': False},
#  {'invoice_id': 309022,
#   'created_on': '2019-04-18',
#   'invoiceitem_id': 197972,
#   'invoiceitem_name': 'ii_197972',
#   'type': 'Other',
#   'unit_price': 145,
#   'total_price': 435,
#   'percentage_in_invoice': 10.646108663729809,
#   'is_expired': False},
#  {'invoice_id': 309022,
#   'created_on': '2019-04-18',
#   'invoiceitem_id': 123298,
#   'invoiceitem_name': 'ii_123298',
#   'type': 'Service',
#   'unit_price': 189,
#   'total_price': 756,
#   'percentage_in_invoice': 18.502202643171806,
#   'is_expired': False},
#  {'invoice_id': 309022,
#   'created_on': '2019-04-18',
#   'invoiceitem_id': 105792,
#   'invoiceitem_name': 'ii_105792',
#   'type': 'Other',
#   'unit_price': 106,
#   'total_price': 742,
#   'percentage_in_invoice': 18.159569260890844,
#   'is_expired': False},
#  {'invoice_id': 309022,
#   'created_on': '2019-04-18',
#   'invoiceitem_id': 109859,
#   'invoiceitem_name': 'ii_109859',
#   'type': 'Service',
#   'unit_price': 117,
#   'total_price': 936,
#   'percentage_in_invoice': 22.90748898678414,
#   'is_expired': False},
#  {'invoice_id': 309022,
#   'created_on': '2019-04-18',
#   'invoiceitem_id': 171220,
#   'invoiceitem_name': 'ii_171220',
#   'type': 'Other',
#   'unit_price': 136,
#   'total_price': 816,
#   'percentage_in_invoice': 19.970631424375917,
#   'is_expired': False},
#  {'invoice_id': 309022,
#   'created_on': '2019-04-18',
#   'invoiceitem_id': 131338,
#   'invoiceitem_name': 'ii_131338',
#   'type': 'Equipment',
#   'unit_price': 197,
#   'total_price': 197,
#   'percentage_in_invoice': 4.8213411649535,
#   'is_expired': False},
#  {'invoice_id': '325156O',
#   'created_on': '2019-06-25',
#   'invoiceitem_id': 169797,
#   'invoiceitem_name': 'ii_169797',
#   'type': 'Other',
#   'unit_price': 116,
#   'total_price': 812,
#   'percentage_in_invoice': 15.056554793250509,
#   'is_expired': False},
#  {'invoice_id': '325156O',
#   'created_on': '2019-06-25',
#   'invoiceitem_id': 132735,
#   'invoiceitem_name': 'ii_132735',
#   'type': 'Equipment',
#   'unit_price': 181,
#   'total_price': 1267,
#   'percentage_in_invoice': 23.493417392916744,
#   'is_expired': False},
#  {'invoice_id': '325156O',
#   'created_on': '2019-06-25',
#   'invoiceitem_id': 109190,
#   'invoiceitem_name': 'ii_109190',
#   'type': 'Service',
#   'unit_price': 189,
#   'total_price': 1134,
#   'percentage_in_invoice': 21.027257556091232,
#   'is_expired': False},
#  {'invoice_id': '325156O',
#   'created_on': '2019-06-25',
#   'invoiceitem_id': 150736,
#   'invoiceitem_name': 'ii_150736',
#   'type': 'Equipment',
#   'unit_price': 138,
#   'total_price': 690,
#   'percentage_in_invoice': 12.794363063230113,
#   'is_expired': False},
#  {'invoice_id': '325156O',
#   'created_on': '2019-06-25',
#   'invoiceitem_id': 142199,
#   'invoiceitem_name': 'ii_142199',
#   'type': 'Service',
#   'unit_price': 130,
#   'total_price': 520,
#   'percentage_in_invoice': 9.642128685332839,
#   'is_expired': False},
#  {'invoice_id': '325156O',
#   'created_on': '2019-06-25',
#   'invoiceitem_id': 197255,
#   'invoiceitem_name': 'ii_197255',
#   'type': 'Service',
#   'unit_price': 142,
#   'total_price': 710,
#   'percentage_in_invoice': 13.165214166512145,
#   'is_expired': False},
#  {'invoice_id': '325156O',
#   'created_on': '2019-06-25',
#   'invoiceitem_id': 119673,
#   'invoiceitem_name': 'ii_119673',
#   'type': 'Material',
#   'unit_price': 130,
#   'total_price': 260,
#   'percentage_in_invoice': 4.8210643426664195,
#   'is_expired': False},
#  {'invoice_id': 316710,
#   'created_on': '2019-05-25',
#   'invoiceitem_id': 182123,
#   'invoiceitem_name': 'ii_182123',
#   'type': 'Equipment',
#   'unit_price': 137,
#   'total_price': 548,
#   'percentage_in_invoice': 31.494252873563216,
#   'is_expired': False},
#  {'invoice_id': 316710,
#   'created_on': '2019-05-25',
#   'invoiceitem_id': 135307,
#   'invoiceitem_name': 'ii_135307',
#   'type': 'Other',
#   'unit_price': 149,
#   'total_price': 1192,
#   'percentage_in_invoice': 68.50574712643677,
#   'is_expired': False},
#  {'invoice_id': 370388,
#   'created_on': '2019-09-12',
#   'invoiceitem_id': 183848,
#   'invoiceitem_name': 'ii_183848',
#   'type': 'Other',
#   'unit_price': 112,
#   'total_price': 784,
#   'percentage_in_invoice': 14.123581336696093,
#   'is_expired': False},
#  {'invoice_id': 370388,
#   'created_on': '2019-09-12',
#   'invoiceitem_id': 165619,
#   'invoiceitem_name': 'ii_165619',
#   'type': 'Material',
#   'unit_price': 142,
#   'total_price': 994,
#   'percentage_in_invoice': 17.90668348045397,
#   'is_expired': False},
#  {'invoice_id': 370388,
#   'created_on': '2019-09-12',
#   'invoiceitem_id': 181685,
#   'invoiceitem_name': 'ii_181685',
#   'type': 'Other',
#   'unit_price': 200,
#   'total_price': 800,
#   'percentage_in_invoice': 14.411817690506215,
#   'is_expired': False},
#  {'invoice_id': 370388,
#   'created_on': '2019-09-12',
#   'invoiceitem_id': 124709,
#   'invoiceitem_name': 'ii_124709',
#   'type': 'Service',
#   'unit_price': 115,
#   'total_price': 460,
#   'percentage_in_invoice': 8.286795172041074,
#   'is_expired': False},
#  {'invoice_id': 370388,
#   'created_on': '2019-09-12',
#   'invoiceitem_id': 129808,
#   'invoiceitem_name': 'ii_129808',
#   'type': 'Equipment',
#   'unit_price': 185,
#   'total_price': 925,
#   'percentage_in_invoice': 16.66366420464781,
#   'is_expired': False},
#  {'invoice_id': 370388,
#   'created_on': '2019-09-12',
#   'invoiceitem_id': 112870,
#   'invoiceitem_name': 'ii_112870',
#   'type': 'Equipment',
#   'unit_price': 102,
#   'total_price': 204,
#   'percentage_in_invoice': 3.675013511079085,
#   'is_expired': False},
#  {'invoice_id': 370388,
#   'created_on': '2019-09-12',
#   'invoiceitem_id': 102035,
#   'invoiceitem_name': 'ii_102035',
#   'type': 'Service',
#   'unit_price': 173,
#   'total_price': 1384,
#   'percentage_in_invoice': 24.93244460457575,
#   'is_expired': False},
#  {'invoice_id': 307923,
#   'created_on': '2019-04-20',
#   'invoiceitem_id': 118576,
#   'invoiceitem_name': 'ii_118576',
#   'type': 'Other',
#   'unit_price': 183,
#   'total_price': 732,
#   'percentage_in_invoice': 53.98230088495575,
#   'is_expired': False},
#  {'invoice_id': 307923,
#   'created_on': '2019-04-20',
#   'invoiceitem_id': 103717,
#   'invoiceitem_name': 'ii_103717',
#   'type': 'Other',
#   'unit_price': 100,
#   'total_price': 200,
#   'percentage_in_invoice': 14.749262536873156,
#   'is_expired': False},
#  {'invoice_id': 307923,
#   'created_on': '2019-04-20',
#   'invoiceitem_id': 127738,
#   'invoiceitem_name': 'ii_127738',
#   'type': 'Material',
#   'unit_price': 106,
#   'total_price': 424,
#   'percentage_in_invoice': 31.268436578171094,
#   'is_expired': False},
#  {'invoice_id': '326649O',
#   'created_on': '2019-02-27',
#   'invoiceitem_id': 170022,
#   'invoiceitem_name': 'ii_170022',
#   'type': 'Equipment',
#   'unit_price': 190,
#   'total_price': 1330,
#   'percentage_in_invoice': 38.68528214077953,
#   'is_expired': False},
#  {'invoice_id': '326649O',
#   'created_on': '2019-02-27',
#   'invoiceitem_id': 177477,
#   'invoiceitem_name': 'ii_177477',
#   'type': 'Other',
#   'unit_price': 116,
#   'total_price': 580,
#   'percentage_in_invoice': 16.870273414776033,
#   'is_expired': False},
#  {'invoice_id': '326649O',
#   'created_on': '2019-02-27',
#   'invoiceitem_id': 170207,
#   'invoiceitem_name': 'ii_170207',
#   'type': 'Equipment',
#   'unit_price': 191,
#   'total_price': 1528,
#   'percentage_in_invoice': 44.44444444444444,
#   'is_expired': False},
#  {'invoice_id': 369292,
#   'created_on': '2019-09-13',
#   'invoiceitem_id': 125771,
#   'invoiceitem_name': 'ii_125771',
#   'type': 'Equipment',
#   'unit_price': 194,
#   'total_price': 1358,
#   'percentage_in_invoice': 39.30535455861071,
#   'is_expired': False},
#  {'invoice_id': 369292,
#   'created_on': '2019-09-13',
#   'invoiceitem_id': 107345,
#   'invoiceitem_name': 'ii_107345',
#   'type': 'Service',
#   'unit_price': 120,
#   'total_price': 360,
#   'percentage_in_invoice': 10.419681620839363,
#   'is_expired': False},
#  {'invoice_id': 369292,
#   'created_on': '2019-09-13',
#   'invoiceitem_id': 106241,
#   'invoiceitem_name': 'ii_106241',
#   'type': 'Material',
#   'unit_price': 183,
#   'total_price': 1281,
#   'percentage_in_invoice': 37.0767004341534,
#   'is_expired': False},
#  {'invoice_id': 369292,
#   'created_on': '2019-09-13',
#   'invoiceitem_id': 191895,
#   'invoiceitem_name': 'ii_191895',
#   'type': 'Material',
#   'unit_price': 114,
#   'total_price': 456,
#   'percentage_in_invoice': 13.198263386396528,
#   'is_expired': False},
#  {'invoice_id': 304245,
#   'created_on': '2019-03-17',
#   'invoiceitem_id': 121446,
#   'invoiceitem_name': 'ii_121446',
#   'type': 'Service',
#   'unit_price': 158,
#   'total_price': 632,
#   'percentage_in_invoice': 12.842918106076,
#   'is_expired': False},
#  {'invoice_id': 304245,
#   'created_on': '2019-03-17',
#   'invoiceitem_id': 155308,
#   'invoiceitem_name': 'ii_155308',
#   'type': 'Equipment',
#   'unit_price': 161,
#   'total_price': 1127,
#   'percentage_in_invoice': 22.90184921763869,
#   'is_expired': False},
#  {'invoice_id': 304245,
#   'created_on': '2019-03-17',
#   'invoiceitem_id': 143674,
#   'invoiceitem_name': 'ii_143674',
#   'type': 'Service',
#   'unit_price': 176,
#   'total_price': 528,
#   'percentage_in_invoice': 10.729526519000203,
#   'is_expired': False},
#  {'invoice_id': 304245,
#   'created_on': '2019-03-17',
#   'invoiceitem_id': 161145,
#   'invoiceitem_name': 'ii_161145',
#   'type': 'Service',
#   'unit_price': 191,
#   'total_price': 1146,
#   'percentage_in_invoice': 23.28794960373908,
#   'is_expired': False},
#  {'invoice_id': 304245,
#   'created_on': '2019-03-17',
#   'invoiceitem_id': 155679,
#   'invoiceitem_name': 'ii_155679',
#   'type': 'Service',
#   'unit_price': 194,
#   'total_price': 582,
#   'percentage_in_invoice': 11.826864458443406,
#   'is_expired': False},
#  {'invoice_id': 304245,
#   'created_on': '2019-03-17',
#   'invoiceitem_id': 135235,
#   'invoiceitem_name': 'ii_135235',
#   'type': 'Service',
#   'unit_price': 151,
#   'total_price': 906,
#   'percentage_in_invoice': 18.41089209510262,
#   'is_expired': False},
#  {'invoice_id': 392733,
#   'created_on': '2019-07-12',
#   'invoiceitem_id': 149945,
#   'invoiceitem_name': 'ii_149945',
#   'type': 'Other',
#   'unit_price': 116,
#   'total_price': 812,
#   'percentage_in_invoice': 35.15151515151515,
#   'is_expired': False},
#  {'invoice_id': 392733,
#   'created_on': '2019-07-12',
#   'invoiceitem_id': 122938,
#   'invoiceitem_name': 'ii_122938',
#   'type': 'Other',
#   'unit_price': 120,
#   'total_price': 120,
#   'percentage_in_invoice': 5.194805194805195,
#   'is_expired': False},
#  {'invoice_id': 392733,
#   'created_on': '2019-07-12',
#   'invoiceitem_id': 196413,
#   'invoiceitem_name': 'ii_196413',
#   'type': 'Material',
#   'unit_price': 125,
#   'total_price': 1000,
#   'percentage_in_invoice': 43.290043290043286,
#   'is_expired': False},
#  {'invoice_id': 392733,
#   'created_on': '2019-07-12',
#   'invoiceitem_id': 142303,
#   'invoiceitem_name': 'ii_142303',
#   'type': 'Other',
#   'unit_price': 126,
#   'total_price': 378,
#   'percentage_in_invoice': 16.363636363636363,
#   'is_expired': False},
#  {'invoice_id': 335732,
#   'created_on': '2019-08-10',
#   'invoiceitem_id': 178111,
#   'invoiceitem_name': 'ii_178111',
#   'type': 'Other',
#   'unit_price': 187,
#   'total_price': 1122,
#   'percentage_in_invoice': 34.683153013910356,
#   'is_expired': False},
#  {'invoice_id': 335732,
#   'created_on': '2019-08-10',
#   'invoiceitem_id': 134919,
#   'invoiceitem_name': 'ii_134919',
#   'type': 'Other',
#   'unit_price': 158,
#   'total_price': 474,
#   'percentage_in_invoice': 14.65224111282844,
#   'is_expired': False},
#  {'invoice_id': 335732,
#   'created_on': '2019-08-10',
#   'invoiceitem_id': 198017,
#   'invoiceitem_name': 'ii_198017',
#   'type': 'Service',
#   'unit_price': 152,
#   'total_price': 304,
#   'percentage_in_invoice': 9.397217928902627,
#   'is_expired': False},
#  {'invoice_id': 335732,
#   'created_on': '2019-08-10',
#   'invoiceitem_id': 189409,
#   'invoiceitem_name': 'ii_189409',
#   'type': 'Service',
#   'unit_price': 194,
#   'total_price': 1164,
#   'percentage_in_invoice': 35.981452859350846,
#   'is_expired': False},
#  {'invoice_id': 335732,
#   'created_on': '2019-08-10',
#   'invoiceitem_id': 159222,
#   'invoiceitem_name': 'ii_159222',
#   'type': 'Service',
#   'unit_price': 171,
#   'total_price': 171,
#   'percentage_in_invoice': 5.285935085007728,
#   'is_expired': False},
#  {'invoice_id': 363284,
#   'created_on': '2019-09-21',
#   'invoiceitem_id': 107763,
#   'invoiceitem_name': 'ii_107763',
#   'type': 'Other',
#   'unit_price': 110,
#   'total_price': 660,
#   'percentage_in_invoice': 9.629413481178874,
#   'is_expired': False},
#  {'invoice_id': 363284,
#   'created_on': '2019-09-21',
#   'invoiceitem_id': 180493,
#   'invoiceitem_name': 'ii_180493',
#   'type': 'Equipment',
#   'unit_price': 144,
#   'total_price': 720,
#   'percentage_in_invoice': 10.50481470674059,
#   'is_expired': False},
#  {'invoice_id': 363284,
#   'created_on': '2019-09-21',
#   'invoiceitem_id': 154557,
#   'invoiceitem_name': 'ii_154557',
#   'type': 'Material',
#   'unit_price': 131,
#   'total_price': 393,
#   'percentage_in_invoice': 5.733878027429238,
#   'is_expired': False},
#  {'invoice_id': 363284,
#   'created_on': '2019-09-21',
#   'invoiceitem_id': 147178,
#   'invoiceitem_name': 'ii_147178',
#   'type': 'Material',
#   'unit_price': 165,
#   'total_price': 825,
#   'percentage_in_invoice': 12.036766851473592,
#   'is_expired': False},
#  {'invoice_id': 363284,
#   'created_on': '2019-09-21',
#   'invoiceitem_id': 171334,
#   'invoiceitem_name': 'ii_171334',
#   'type': 'Material',
#   'unit_price': 172,
#   'total_price': 1032,
#   'percentage_in_invoice': 15.056901079661511,
#   'is_expired': False},
#  {'invoice_id': 363284,
#   'created_on': '2019-09-21',
#   'invoiceitem_id': 128292,
#   'invoiceitem_name': 'ii_128292',
#   'type': 'Service',
#   'unit_price': 134,
#   'total_price': 804,
#   'percentage_in_invoice': 11.730376422526993,
#   'is_expired': False},
#  {'invoice_id': 363284,
#   'created_on': '2019-09-21',
#   'invoiceitem_id': 170804,
#   'invoiceitem_name': 'ii_170804',
#   'type': 'Material',
#   'unit_price': 195,
#   'total_price': 1560,
#   'percentage_in_invoice': 22.76043186460461,
#   'is_expired': False},
#  {'invoice_id': 363284,
#   'created_on': '2019-09-21',
#   'invoiceitem_id': 144611,
#   'invoiceitem_name': 'ii_144611',
#   'type': 'Equipment',
#   'unit_price': 172,
#   'total_price': 860,
#   'percentage_in_invoice': 12.547417566384592,
#   'is_expired': False},
#  {'invoice_id': 373241,
#   'created_on': '2019-02-19',
#   'invoiceitem_id': 196536,
#   'invoiceitem_name': 'ii_196536',
#   'type': 'Other',
#   'unit_price': 196,
#   'total_price': 1372,
#   'percentage_in_invoice': 40.57971014492754,
#   'is_expired': False},
#  {'invoice_id': 373241,
#   'created_on': '2019-02-19',
#   'invoiceitem_id': 161678,
#   'invoiceitem_name': 'ii_161678',
#   'type': 'Service',
#   'unit_price': 140,
#   'total_price': 840,
#   'percentage_in_invoice': 24.84472049689441,
#   'is_expired': False},
#  {'invoice_id': 373241,
#   'created_on': '2019-02-19',
#   'invoiceitem_id': 116519,
#   'invoiceitem_name': 'ii_116519',
#   'type': 'Equipment',
#   'unit_price': 161,
#   'total_price': 161,
#   'percentage_in_invoice': 4.761904761904762,
#   'is_expired': False},
#  {'invoice_id': 373241,
#   'created_on': '2019-02-19',
#   'invoiceitem_id': 118309,
#   'invoiceitem_name': 'ii_118309',
#   'type': 'Material',
#   'unit_price': 126,
#   'total_price': 1008,
#   'percentage_in_invoice': 29.81366459627329,
#   'is_expired': False},
#  {'invoice_id': '385290O',
#   'created_on': '2019-06-29',
#   'invoiceitem_id': 150069,
#   'invoiceitem_name': 'ii_150069',
#   'type': 'Other',
#   'unit_price': 114,
#   'total_price': 798,
#   'percentage_in_invoice': 77.47572815533981,
#   'is_expired': False},
#  {'invoice_id': '385290O',
#   'created_on': '2019-06-29',
#   'invoiceitem_id': 168488,
#   'invoiceitem_name': 'ii_168488',
#   'type': 'Equipment',
#   'unit_price': 116,
#   'total_price': 232,
#   'percentage_in_invoice': 22.52427184466019,
#   'is_expired': False},
#  {'invoice_id': 394428,
#   'created_on': '2019-09-26',
#   'invoiceitem_id': 141154,
#   'invoiceitem_name': 'ii_141154',
#   'type': 'Equipment',
#   'unit_price': 129,
#   'total_price': 645,
#   'percentage_in_invoice': 14.374860708714063,
#   'is_expired': True},
#  {'invoice_id': 394428,
#   'created_on': '2019-09-26',
#   'invoiceitem_id': 120256,
#   'invoiceitem_name': 'ii_120256',
#   'type': 'Other',
#   'unit_price': 100,
#   'total_price': 500,
#   'percentage_in_invoice': 11.143302874972141,
#   'is_expired': True},
#  {'invoice_id': 394428,
#   'created_on': '2019-09-26',
#   'invoiceitem_id': 192645,
#   'invoiceitem_name': 'ii_192645',
#   'type': 'Equipment',
#   'unit_price': 102,
#   'total_price': 816,
#   'percentage_in_invoice': 18.185870291954533,
#   'is_expired': True},
#  {'invoice_id': 394428,
#   'created_on': '2019-09-26',
#   'invoiceitem_id': 194735,
#   'invoiceitem_name': 'ii_194735',
#   'type': 'Material',
#   'unit_price': 100,
#   'total_price': 300,
#   'percentage_in_invoice': 6.685981724983285,
#   'is_expired': True},
#  {'invoice_id': 394428,
#   'created_on': '2019-09-26',
#   'invoiceitem_id': 141457,
#   'invoiceitem_name': 'ii_141457',
#   'type': 'Equipment',
#   'unit_price': 181,
#   'total_price': 1267,
#   'percentage_in_invoice': 28.23712948517941,
#   'is_expired': True},
#  {'invoice_id': 394428,
#   'created_on': '2019-09-26',
#   'invoiceitem_id': 160040,
#   'invoiceitem_name': 'ii_160040',
#   'type': 'Material',
#   'unit_price': 137,
#   'total_price': 959,
#   'percentage_in_invoice': 21.37285491419657,
#   'is_expired': True},
#  {'invoice_id': 326452,
#   'created_on': '2019-08-21',
#   'invoiceitem_id': 155752,
#   'invoiceitem_name': 'ii_155752',
#   'type': 'Equipment',
#   'unit_price': 102,
#   'total_price': 408,
#   'percentage_in_invoice': 16.139240506329113,
#   'is_expired': True},
#  {'invoice_id': 326452,
#   'created_on': '2019-08-21',
#   'invoiceitem_id': 157444,
#   'invoiceitem_name': 'ii_157444',
#   'type': 'Service',
#   'unit_price': 154,
#   'total_price': 154,
#   'percentage_in_invoice': 6.091772151898734,
#   'is_expired': True},
#  {'invoice_id': 326452,
#   'created_on': '2019-08-21',
#   'invoiceitem_id': 124339,
#   'invoiceitem_name': 'ii_124339',
#   'type': 'Equipment',
#   'unit_price': 200,
#   'total_price': 800,
#   'percentage_in_invoice': 31.645569620253166,
#   'is_expired': True},
#  {'invoice_id': 326452,
#   'created_on': '2019-08-21',
#   'invoiceitem_id': 154969,
#   'invoiceitem_name': 'ii_154969',
#   'type': 'Other',
#   'unit_price': 151,
#   'total_price': 302,
#   'percentage_in_invoice': 11.94620253164557,
#   'is_expired': True},
#  {'invoice_id': 326452,
#   'created_on': '2019-08-21',
#   'invoiceitem_id': 168281,
#   'invoiceitem_name': 'ii_168281',
#   'type': 'Other',
#   'unit_price': 144,
#   'total_price': 864,
#   'percentage_in_invoice': 34.177215189873415,
#   'is_expired': True},
#  {'invoice_id': 342057,
#   'created_on': '2019-07-14',
#   'invoiceitem_id': 143077,
#   'invoiceitem_name': 'ii_143077',
#   'type': 'Material',
#   'unit_price': 103,
#   'total_price': 412,
#   'percentage_in_invoice': 24.93946731234867,
#   'is_expired': False},
#  {'invoice_id': 342057,
#   'created_on': '2019-07-14',
#   'invoiceitem_id': 119152,
#   'invoiceitem_name': 'ii_119152',
#   'type': 'Service',
#   'unit_price': 155,
#   'total_price': 1240,
#   'percentage_in_invoice': 75.06053268765133,
#   'is_expired': False},
#  {'invoice_id': 356817,
#   'created_on': '2019-05-14',
#   'invoiceitem_id': 182969,
#   'invoiceitem_name': 'ii_182969',
#   'type': 'Other',
#   'unit_price': 107,
#   'total_price': 749,
#   'percentage_in_invoice': 18.304007820136853,
#   'is_expired': False},
#  {'invoice_id': 356817,
#   'created_on': '2019-05-14',
#   'invoiceitem_id': 126581,
#   'invoiceitem_name': 'ii_126581',
#   'type': 'Equipment',
#   'unit_price': 115,
#   'total_price': 345,
#   'percentage_in_invoice': 8.431085043988269,
#   'is_expired': False},
#  {'invoice_id': 356817,
#   'created_on': '2019-05-14',
#   'invoiceitem_id': 156873,
#   'invoiceitem_name': 'ii_156873',
#   'type': 'Equipment',
#   'unit_price': 166,
#   'total_price': 332,
#   'percentage_in_invoice': 8.113391984359726,
#   'is_expired': False},
#  {'invoice_id': 356817,
#   'created_on': '2019-05-14',
#   'invoiceitem_id': 129822,
#   'invoiceitem_name': 'ii_129822',
#   'type': 'Service',
#   'unit_price': 117,
#   'total_price': 468,
#   'percentage_in_invoice': 11.436950146627565,
#   'is_expired': False},
#  {'invoice_id': 356817,
#   'created_on': '2019-05-14',
#   'invoiceitem_id': 192836,
#   'invoiceitem_name': 'ii_192836',
#   'type': 'Other',
#   'unit_price': 171,
#   'total_price': 684,
#   'percentage_in_invoice': 16.715542521994134,
#   'is_expired': False},
#  {'invoice_id': 356817,
#   'created_on': '2019-05-14',
#   'invoiceitem_id': 190522,
#   'invoiceitem_name': 'ii_190522',
#   'type': 'Other',
#   'unit_price': 156,
#   'total_price': 624,
#   'percentage_in_invoice': 15.249266862170089,
#   'is_expired': False},
#  {'invoice_id': 356817,
#   'created_on': '2019-05-14',
#   'invoiceitem_id': 189295,
#   'invoiceitem_name': 'ii_189295',
#   'type': 'Service',
#   'unit_price': 178,
#   'total_price': 890,
#   'percentage_in_invoice': 21.749755620723363,
#   'is_expired': False},
#  {'invoice_id': '381476O',
#   'created_on': '2019-07-12',
#   'invoiceitem_id': 195222,
#   'invoiceitem_name': 'ii_195222',
#   'type': 'Other',
#   'unit_price': 186,
#   'total_price': 1488,
#   'percentage_in_invoice': 60.41412911084044,
#   'is_expired': False},
#  {'invoice_id': '381476O',
#   'created_on': '2019-07-12',
#   'invoiceitem_id': 121779,
#   'invoiceitem_name': 'ii_121779',
#   'type': 'Service',
#   'unit_price': 195,
#   'total_price': 975,
#   'percentage_in_invoice': 39.585870889159565,
#   'is_expired': False},
#  {'invoice_id': 322229,
#   'created_on': '2019-07-27',
#   'invoiceitem_id': 113336,
#   'invoiceitem_name': 'ii_113336',
#   'type': 'Material',
#   'unit_price': 121,
#   'total_price': 363,
#   'percentage_in_invoice': 8.469435370975269,
#   'is_expired': True},
#  {'invoice_id': 322229,
#   'created_on': '2019-07-27',
#   'invoiceitem_id': 153568,
#   'invoiceitem_name': 'ii_153568',
#   'type': 'Equipment',
#   'unit_price': 127,
#   'total_price': 1016,
#   'percentage_in_invoice': 23.70508632757816,
#   'is_expired': True},
#  {'invoice_id': 322229,
#   'created_on': '2019-07-27',
#   'invoiceitem_id': 101063,
#   'invoiceitem_name': 'ii_101063',
#   'type': 'Other',
#   'unit_price': 149,
#   'total_price': 298,
#   'percentage_in_invoice': 6.952869808679421,
#   'is_expired': True},
#  {'invoice_id': 322229,
#   'created_on': '2019-07-27',
#   'invoiceitem_id': 155936,
#   'invoiceitem_name': 'ii_155936',
#   'type': 'Equipment',
#   'unit_price': 171,
#   'total_price': 855,
#   'percentage_in_invoice': 19.948670088660755,
#   'is_expired': True},
#  {'invoice_id': 322229,
#   'created_on': '2019-07-27',
#   'invoiceitem_id': 178996,
#   'invoiceitem_name': 'ii_178996',
#   'type': 'Service',
#   'unit_price': 194,
#   'total_price': 388,
#   'percentage_in_invoice': 9.052729818012132,
#   'is_expired': True},
#  {'invoice_id': 322229,
#   'created_on': '2019-07-27',
#   'invoiceitem_id': 145514,
#   'invoiceitem_name': 'ii_145514',
#   'type': 'Material',
#   'unit_price': 191,
#   'total_price': 191,
#   'percentage_in_invoice': 4.456369575361642,
#   'is_expired': True},
#  {'invoice_id': 322229,
#   'created_on': '2019-07-27',
#   'invoiceitem_id': 130624,
#   'invoiceitem_name': 'ii_130624',
#   'type': 'Material',
#   'unit_price': 167,
#   'total_price': 167,
#   'percentage_in_invoice': 3.8964069062062525,
#   'is_expired': True},
#  {'invoice_id': 322229,
#   'created_on': '2019-07-27',
#   'invoiceitem_id': 178642,
#   'invoiceitem_name': 'ii_178642',
#   'type': 'Service',
#   'unit_price': 126,
#   'total_price': 1008,
#   'percentage_in_invoice': 23.518432104526365,
#   'is_expired': True},
#  {'invoice_id': 377719,
#   'created_on': '2019-01-25',
#   'invoiceitem_id': 157233,
#   'invoiceitem_name': 'ii_157233',
#   'type': 'Equipment',
#   'unit_price': 150,
#   'total_price': 150,
#   'percentage_in_invoice': 5.671077504725898,
#   'is_expired': False},
#  {'invoice_id': 377719,
#   'created_on': '2019-01-25',
#   'invoiceitem_id': 172149,
#   'invoiceitem_name': 'ii_172149',
#   'type': 'Material',
#   'unit_price': 192,
#   'total_price': 1344,
#   'percentage_in_invoice': 50.81285444234405,
#   'is_expired': False},
#  {'invoice_id': 377719,
#   'created_on': '2019-01-25',
#   'invoiceitem_id': 178297,
#   'invoiceitem_name': 'ii_178297',
#   'type': 'Other',
#   'unit_price': 124,
#   'total_price': 992,
# ...
#   'unit_price': 172,
#   'total_price': 516,
#   'percentage_in_invoice': 13.48314606741573,
#   'is_expired': True},
#  {'invoice_id': 343254,
#   'created_on': '2019-07-12',
#   'invoiceitem_id': 128915,
#   'invoiceitem_name': 'ii_128915',
#   'type': 'Service',
#   'unit_price': 109,
#   'total_price': 545,
#   'percentage_in_invoice': 14.240919780506925,
#   'is_expired': True},
#  {'invoice_id': 343254,
#   'created_on': '2019-07-12',
#   'invoiceitem_id': 177697,
#   'invoiceitem_name': 'ii_177697',
#   'type': 'Equipment',
#   'unit_price': 123,
#   'total_price': 246,
#   'percentage_in_invoice': 6.428011497256336,
#   'is_expired': True},
#  {'invoice_id': 343254,
#   'created_on': '2019-07-12',
#   'invoiceitem_id': 198244,
#   'invoiceitem_name': 'ii_198244',
#   'type': 'Equipment',
#   'unit_price': 119,
#   'total_price': 119,
#   'percentage_in_invoice': 3.1094852364776586,
#   'is_expired': True},
#  {'invoice_id': 343254,
#   'created_on': '2019-07-12',
#   'invoiceitem_id': 134480,
#   'invoiceitem_name': 'ii_134480',
#   'type': 'Material',
#   'unit_price': 127,
#   'total_price': 508,
#   'percentage_in_invoice': 13.274105043114712,
#   'is_expired': True},
#  {'invoice_id': 343254,
#   'created_on': '2019-07-12',
#   'invoiceitem_id': 187069,
#   'invoiceitem_name': 'ii_187069',
#   'type': 'Equipment',
#   'unit_price': 111,
#   'total_price': 333,
#   'percentage_in_invoice': 8.70133263652992,
#   'is_expired': True},
#  {'invoice_id': 343254,
#   'created_on': '2019-07-12',
#   'invoiceitem_id': 163211,
#   'invoiceitem_name': 'ii_163211',
#   'type': 'Other',
#   'unit_price': 142,
#   'total_price': 426,
#   'percentage_in_invoice': 11.131434544029267,
#   'is_expired': True},
#  {'invoice_id': 343254,
#   'created_on': '2019-07-12',
#   'invoiceitem_id': 138776,
#   'invoiceitem_name': 'ii_138776',
#   'type': 'Material',
#   'unit_price': 189,
#   'total_price': 1134,
#   'percentage_in_invoice': 29.631565194669452,
#   'is_expired': True},
#  {'invoice_id': 330931,
#   'created_on': '2019-03-20',
#   'invoiceitem_id': 163035,
#   'invoiceitem_name': 'ii_163035',
#   'type': 'Service',
#   'unit_price': 123,
#   'total_price': 984,
#   'percentage_in_invoice': 21.76991150442478,
#   'is_expired': True},
#  {'invoice_id': 330931,
#   'created_on': '2019-03-20',
#   'invoiceitem_id': 182320,
#   'invoiceitem_name': 'ii_182320',
#   'type': 'Service',
#   'unit_price': 106,
#   'total_price': 318,
#   'percentage_in_invoice': 7.035398230088495,
#   'is_expired': True},
#  {'invoice_id': 330931,
#   'created_on': '2019-03-20',
#   'invoiceitem_id': 103864,
#   'invoiceitem_name': 'ii_103864',
#   'type': 'Service',
#   'unit_price': 148,
#   'total_price': 888,
#   'percentage_in_invoice': 19.646017699115045,
#   'is_expired': True},
#  {'invoice_id': 330931,
#   'created_on': '2019-03-20',
#   'invoiceitem_id': 185413,
#   'invoiceitem_name': 'ii_185413',
#   'type': 'Equipment',
#   'unit_price': 161,
#   'total_price': 1288,
#   'percentage_in_invoice': 28.49557522123894,
#   'is_expired': True},
#  {'invoice_id': 330931,
#   'created_on': '2019-03-20',
#   'invoiceitem_id': 108965,
#   'invoiceitem_name': 'ii_108965',
#   'type': 'Other',
#   'unit_price': 138,
#   'total_price': 414,
#   'percentage_in_invoice': 9.159292035398229,
#   'is_expired': True},
#  {'invoice_id': 330931,
#   'created_on': '2019-03-20',
#   'invoiceitem_id': 175469,
#   'invoiceitem_name': 'ii_175469',
#   'type': 'Other',
#   'unit_price': 157,
#   'total_price': 628,
#   'percentage_in_invoice': 13.893805309734514,
#   'is_expired': True},
#  {'invoice_id': 375592,
#   'created_on': '2019-02-30',
#   'invoiceitem_id': 157027,
#   'invoiceitem_name': 'ii_157027',
#   'type': 'Equipment',
#   'unit_price': 187,
#   'total_price': -187,
#   'percentage_in_invoice': -65.84507042253522,
#   'is_expired': False},
#  {'invoice_id': 375592,
#   'created_on': '2019-02-30',
#   'invoiceitem_id': 185821,
#   'invoiceitem_name': 'ii_185821',
#   'type': 'Service',
#   'unit_price': 157,
#   'total_price': 471,
#   'percentage_in_invoice': 165.8450704225352,
#   'is_expired': False},
#  {'invoice_id': 386678,
#   'created_on': '2019-09-18',
#   'invoiceitem_id': 133300,
#   'invoiceitem_name': 'ii_133300',
#   'type': 'Equipment',
#   'unit_price': 130,
#   'total_price': 910,
#   'percentage_in_invoice': 43.27151688064669,
#   'is_expired': False},
#  {'invoice_id': 386678,
#   'created_on': '2019-09-18',
#   'invoiceitem_id': 124026,
#   'invoiceitem_name': 'ii_124026',
#   'type': 'Material',
#   'unit_price': 141,
#   'total_price': 423,
#   'percentage_in_invoice': 20.114122681883025,
#   'is_expired': False},
#  {'invoice_id': 386678,
#   'created_on': '2019-09-18',
#   'invoiceitem_id': 128660,
#   'invoiceitem_name': 'ii_128660',
#   'type': 'Other',
#   'unit_price': 196,
#   'total_price': 392,
#   'percentage_in_invoice': 18.640038040893963,
#   'is_expired': False},
#  {'invoice_id': 386678,
#   'created_on': '2019-09-18',
#   'invoiceitem_id': 143179,
#   'invoiceitem_name': 'ii_143179',
#   'type': 'Equipment',
#   'unit_price': 126,
#   'total_price': 378,
#   'percentage_in_invoice': 17.97432239657632,
#   'is_expired': False},
#  {'invoice_id': 360664,
#   'created_on': '2019-06-26',
#   'invoiceitem_id': 180674,
#   'invoiceitem_name': 'ii_180674',
#   'type': 'Other',
#   'unit_price': 114,
#   'total_price': 114,
#   'percentage_in_invoice': 3.3129904097646032,
#   'is_expired': False},
#  {'invoice_id': 360664,
#   'created_on': '2019-06-26',
#   'invoiceitem_id': 149216,
#   'invoiceitem_name': 'ii_149216',
#   'type': 'Other',
#   'unit_price': 192,
#   'total_price': 384,
#   'percentage_in_invoice': 11.159546643417611,
#   'is_expired': False},
#  {'invoice_id': 360664,
#   'created_on': '2019-06-26',
#   'invoiceitem_id': 156311,
#   'invoiceitem_name': 'ii_156311',
#   'type': 'Equipment',
#   'unit_price': 140,
#   'total_price': 560,
#   'percentage_in_invoice': 16.274338854984016,
#   'is_expired': False},
#  {'invoice_id': 360664,
#   'created_on': '2019-06-26',
#   'invoiceitem_id': 147252,
#   'invoiceitem_name': 'ii_147252',
#   'type': 'Service',
#   'unit_price': 166,
#   'total_price': 996,
#   'percentage_in_invoice': 28.945074106364427,
#   'is_expired': False},
#  {'invoice_id': 360664,
#   'created_on': '2019-06-26',
#   'invoiceitem_id': 112615,
#   'invoiceitem_name': 'ii_112615',
#   'type': 'Equipment',
#   'unit_price': 175,
#   'total_price': 700,
#   'percentage_in_invoice': 20.342923568730022,
#   'is_expired': False},
#  {'invoice_id': 360664,
#   'created_on': '2019-06-26',
#   'invoiceitem_id': 172997,
#   'invoiceitem_name': 'ii_172997',
#   'type': 'Material',
#   'unit_price': 171,
#   'total_price': 171,
#   'percentage_in_invoice': 4.969485614646905,
#   'is_expired': False},
#  {'invoice_id': 360664,
#   'created_on': '2019-06-26',
#   'invoiceitem_id': 133577,
#   'invoiceitem_name': 'ii_133577',
#   'type': 'Service',
#   'unit_price': 172,
#   'total_price': 516,
#   'percentage_in_invoice': 14.995640802092414,
#   'is_expired': False},
#  {'invoice_id': 387341,
#   'created_on': '2019-01-27',
#   'invoiceitem_id': 104043,
#   'invoiceitem_name': 'ii_104043',
#   'type': 'Material',
#   'unit_price': 155,
#   'total_price': 155,
#   'percentage_in_invoice': 6.509869802603947,
#   'is_expired': False},
#  {'invoice_id': 387341,
#   'created_on': '2019-01-27',
#   'invoiceitem_id': 147191,
#   'invoiceitem_name': 'ii_147191',
#   'type': 'Service',
#   'unit_price': 109,
#   'total_price': 218,
#   'percentage_in_invoice': 9.155816883662327,
#   'is_expired': False},
#  {'invoice_id': 387341,
#   'created_on': '2019-01-27',
#   'invoiceitem_id': 178083,
#   'invoiceitem_name': 'ii_178083',
#   'type': 'Material',
#   'unit_price': 148,
#   'total_price': 592,
#   'percentage_in_invoice': 24.8635027299454,
#   'is_expired': False},
#  {'invoice_id': 387341,
#   'created_on': '2019-01-27',
#   'invoiceitem_id': 195056,
#   'invoiceitem_name': 'ii_195056',
#   'type': 'Material',
#   'unit_price': 177,
#   'total_price': 1416,
#   'percentage_in_invoice': 59.47081058378833,
#   'is_expired': False},
#  {'invoice_id': 305869,
#   'created_on': '2019-09-11',
#   'invoiceitem_id': 122089,
#   'invoiceitem_name': 'ii_122089',
#   'type': 'Material',
#   'unit_price': 126,
#   'total_price': 252,
#   'percentage_in_invoice': 8.839003858295335,
#   'is_expired': True},
#  {'invoice_id': 305869,
#   'created_on': '2019-09-11',
#   'invoiceitem_id': 167832,
#   'invoiceitem_name': 'ii_167832',
#   'type': 'Material',
#   'unit_price': 179,
#   'total_price': 716,
#   'percentage_in_invoice': 25.113995089442305,
#   'is_expired': True},
#  {'invoice_id': 305869,
#   'created_on': '2019-09-11',
#   'invoiceitem_id': 192367,
#   'invoiceitem_name': 'ii_192367',
#   'type': 'Material',
#   'unit_price': 156,
#   'total_price': 468,
#   'percentage_in_invoice': 16.415292879691336,
#   'is_expired': True},
#  {'invoice_id': 305869,
#   'created_on': '2019-09-11',
#   'invoiceitem_id': 121559,
#   'invoiceitem_name': 'ii_121559',
#   'type': 'Service',
#   'unit_price': 175,
#   'total_price': 175,
#   'percentage_in_invoice': 6.138197123816204,
#   'is_expired': True},
#  {'invoice_id': 305869,
#   'created_on': '2019-09-11',
#   'invoiceitem_id': 166763,
#   'invoiceitem_name': 'ii_166763',
#   'type': 'Equipment',
#   'unit_price': 155,
#   'total_price': 1240,
#   'percentage_in_invoice': 43.493511048754826,
#   'is_expired': True},
#  {'invoice_id': 356552,
#   'created_on': '2019-03-21',
#   'invoiceitem_id': 112495,
#   'invoiceitem_name': 'ii_112495',
#   'type': 'Equipment',
#   'unit_price': 104,
#   'total_price': 416,
#   'percentage_in_invoice': 22.869708631115998,
#   'is_expired': True},
#  {'invoice_id': 356552,
#   'created_on': '2019-03-21',
#   'invoiceitem_id': 196977,
#   'invoiceitem_name': 'ii_196977',
#   'type': 'Equipment',
#   'unit_price': 160,
#   'total_price': 480,
#   'percentage_in_invoice': 26.38812534359538,
#   'is_expired': True},
#  {'invoice_id': 356552,
#   'created_on': '2019-03-21',
#   'invoiceitem_id': 103631,
#   'invoiceitem_name': 'ii_103631',
#   'type': 'Material',
#   'unit_price': 133,
#   'total_price': 798,
#   'percentage_in_invoice': 43.870258383727325,
#   'is_expired': True},
#  {'invoice_id': 356552,
#   'created_on': '2019-03-21',
#   'invoiceitem_id': 185127,
#   'invoiceitem_name': 'ii_185127',
#   'type': 'Material',
#   'unit_price': 125,
#   'total_price': 125,
#   'percentage_in_invoice': 6.871907641561298,
#   'is_expired': True},
#  {'invoice_id': 306163,
#   'created_on': '2019-09-18',
#   'invoiceitem_id': 136017,
#   'invoiceitem_name': 'ii_136017',
#   'type': 'Equipment',
#   'unit_price': 191,
#   'total_price': 382,
#   'percentage_in_invoice': 11.117578579743888,
#   'is_expired': False},
#  {'invoice_id': 306163,
#   'created_on': '2019-09-18',
#   'invoiceitem_id': 145491,
#   'invoiceitem_name': 'ii_145491',
#   'type': 'Material',
#   'unit_price': 114,
#   'total_price': 228,
#   'percentage_in_invoice': 6.635622817229336,
#   'is_expired': False},
#  {'invoice_id': 306163,
#   'created_on': '2019-09-18',
#   'invoiceitem_id': 167964,
#   'invoiceitem_name': 'ii_167964',
#   'type': 'Service',
#   'unit_price': 127,
#   'total_price': 381,
#   'percentage_in_invoice': 11.08847497089639,
#   'is_expired': False},
#  {'invoice_id': 306163,
#   'created_on': '2019-09-18',
#   'invoiceitem_id': 117418,
#   'invoiceitem_name': 'ii_117418',
#   'type': 'Service',
#   'unit_price': 122,
#   'total_price': 122,
#   'percentage_in_invoice': 3.5506402793946448,
#   'is_expired': False},
#  {'invoice_id': 306163,
#   'created_on': '2019-09-18',
#   'invoiceitem_id': 137129,
#   'invoiceitem_name': 'ii_137129',
#   'type': 'Service',
#   'unit_price': 131,
#   'total_price': 917,
#   'percentage_in_invoice': 26.688009313154833,
#   'is_expired': False},
#  {'invoice_id': 306163,
#   'created_on': '2019-09-18',
#   'invoiceitem_id': 130442,
#   'invoiceitem_name': 'ii_130442',
#   'type': 'Material',
#   'unit_price': 160,
#   'total_price': 320,
#   'percentage_in_invoice': 9.31315483119907,
#   'is_expired': False},
#  {'invoice_id': 306163,
#   'created_on': '2019-09-18',
#   'invoiceitem_id': 108876,
#   'invoiceitem_name': 'ii_108876',
#   'type': 'Material',
#   'unit_price': 181,
#   'total_price': 1086,
#   'percentage_in_invoice': 31.60651920838184,
#   'is_expired': False},
#  {'invoice_id': '373375O',
#   'created_on': '2019-08-24',
#   'invoiceitem_id': 180383,
#   'invoiceitem_name': 'ii_180383',
#   'type': 'Other',
#   'unit_price': 179,
#   'total_price': 1432,
#   'percentage_in_invoice': 20.231703871150042,
#   'is_expired': False},
#  {'invoice_id': '373375O',
#   'created_on': '2019-08-24',
#   'invoiceitem_id': 129478,
#   'invoiceitem_name': 'ii_129478',
#   'type': 'Other',
#   'unit_price': 146,
#   'total_price': 876,
#   'percentage_in_invoice': 12.376377507770558,
#   'is_expired': False},
#  {'invoice_id': '373375O',
#   'created_on': '2019-08-24',
#   'invoiceitem_id': 105522,
#   'invoiceitem_name': 'ii_105522',
#   'type': 'Equipment',
#   'unit_price': 154,
#   'total_price': 1232,
#   'percentage_in_invoice': 17.406046905905622,
#   'is_expired': False},
#  {'invoice_id': '373375O',
#   'created_on': '2019-08-24',
#   'invoiceitem_id': 141924,
#   'invoiceitem_name': 'ii_141924',
#   'type': 'Other',
#   'unit_price': 193,
#   'total_price': 1158,
#   'percentage_in_invoice': 16.360553828765187,
#   'is_expired': False},
#  {'invoice_id': '373375O',
#   'created_on': '2019-08-24',
#   'invoiceitem_id': 182015,
#   'invoiceitem_name': 'ii_182015',
#   'type': 'Service',
#   'unit_price': 149,
#   'total_price': 447,
#   'percentage_in_invoice': 6.315343317321277,
#   'is_expired': False},
#  {'invoice_id': '373375O',
#   'created_on': '2019-08-24',
#   'invoiceitem_id': 159579,
#   'invoiceitem_name': 'ii_159579',
#   'type': 'Service',
#   'unit_price': 178,
#   'total_price': 890,
#   'percentage_in_invoice': 12.574173495337664,
#   'is_expired': False},
#  {'invoice_id': '373375O',
#   'created_on': '2019-08-24',
#   'invoiceitem_id': 157738,
#   'invoiceitem_name': 'ii_157738',
#   'type': 'Other',
#   'unit_price': 130,
#   'total_price': 650,
#   'percentage_in_invoice': 9.183385137044363,
#   'is_expired': False},
#  {'invoice_id': '373375O',
#   'created_on': '2019-08-24',
#   'invoiceitem_id': 139544,
#   'invoiceitem_name': 'ii_139544',
#   'type': 'Other',
#   'unit_price': 131,
#   'total_price': 393,
#   'percentage_in_invoice': 5.552415936705284,
#   'is_expired': False},
#  {'invoice_id': 321243,
#   'created_on': '2019-05-26',
#   'invoiceitem_id': 124775,
#   'invoiceitem_name': 'ii_124775',
#   'type': 'Other',
#   'unit_price': 134,
#   'total_price': 134,
#   'percentage_in_invoice': 6.132723112128147,
#   'is_expired': False},
#  {'invoice_id': 321243,
#   'created_on': '2019-05-26',
#   'invoiceitem_id': 184165,
#   'invoiceitem_name': 'ii_184165',
#   'type': 'Service',
#   'unit_price': 175,
#   'total_price': 875,
#   'percentage_in_invoice': 40.045766590389015,
#   'is_expired': False},
#  {'invoice_id': 321243,
#   'created_on': '2019-05-26',
#   'invoiceitem_id': 155124,
#   'invoiceitem_name': 'ii_155124',
#   'type': 'Service',
#   'unit_price': 127,
#   'total_price': 381,
#   'percentage_in_invoice': 17.4370709382151,
#   'is_expired': False},
#  {'invoice_id': 321243,
#   'created_on': '2019-05-26',
#   'invoiceitem_id': 141626,
#   'invoiceitem_name': 'ii_141626',
#   'type': 'Service',
#   'unit_price': 144,
#   'total_price': 288,
#   'percentage_in_invoice': 13.180778032036613,
#   'is_expired': False},
#  {'invoice_id': 321243,
#   'created_on': '2019-05-26',
#   'invoiceitem_id': 175528,
#   'invoiceitem_name': 'ii_175528',
#   'type': 'Equipment',
#   'unit_price': 169,
#   'total_price': 507,
#   'percentage_in_invoice': 23.20366132723112,
#   'is_expired': False},
#  {'invoice_id': 377960,
#   'created_on': '2019-02-22',
#   'invoiceitem_id': 123242,
#   'invoiceitem_name': 'ii_123242',
#   'type': 'Equipment',
#   'unit_price': 110,
#   'total_price': 550,
#   'percentage_in_invoice': 16.471997604073078,
#   'is_expired': True},
#  {'invoice_id': 377960,
#   'created_on': '2019-02-22',
#   'invoiceitem_id': 196386,
#   'invoiceitem_name': 'ii_196386',
#   'type': 'Other',
#   'unit_price': 150,
#   'total_price': 900,
#   'percentage_in_invoice': 26.954177897574123,
#   'is_expired': True},
#  {'invoice_id': 377960,
#   'created_on': '2019-02-22',
#   'invoiceitem_id': 196707,
#   'invoiceitem_name': 'ii_196707',
#   'type': 'Service',
#   'unit_price': 191,
#   'total_price': 573,
#   'percentage_in_invoice': 17.16082659478886,
#   'is_expired': True},
#  {'invoice_id': 377960,
#   'created_on': '2019-02-22',
#   'invoiceitem_id': 144902,
#   'invoiceitem_name': 'ii_144902',
#   'type': 'Service',
#   'unit_price': 188,
#   'total_price': 1316,
#   'percentage_in_invoice': 39.41299790356394,
#   'is_expired': True}]

# %%
df = pd.DataFrame(transformed_invoices)

# %%
df
# Out:
#     invoice_id  created_on  invoiceitem_id invoiceitem_name       type  \
# 0      365371O  2019-05-27          142446        ii_142446  Equipment
# 1      365371O  2019-05-27          154019        ii_154019  Equipment
# 2       389528  2019-03-19          172535        ii_172535   Material
# 3       389528  2019-03-19          175208        ii_175208   Material
# 4       389528  2019-03-19          139970        ii_139970    Service
# ..         ...         ...             ...              ...        ...
# 483     321243  2019-05-26          175528        ii_175528  Equipment
# 484     377960  2019-02-22          123242        ii_123242  Equipment
# 485     377960  2019-02-22          196386        ii_196386      Other
# 486     377960  2019-02-22          196707        ii_196707    Service
# 487     377960  2019-02-22          144902        ii_144902    Service
#
#      unit_price  total_price  percentage_in_invoice  is_expired
# 0           182         1092              86.119874       False
# 1           176          176              13.880126       False
# 2           105          420               7.331122        True
# 3           109          763              13.318206        True
# 4           193          772              13.475301        True
# ..          ...          ...                    ...         ...
# 483         169          507              23.203661       False
# 484         110          550              16.471998        True
# 485         150          900              26.954178        True
# 486         191          573              17.160827        True
# 487         188         1316              39.412998        True
#
# [488 rows x 9 columns]

# %%
sorted_df = df.sort_values(by=['invoice_id', 'invoiceitem_id'], ascending=[True, True])

# %%
sorted_df.head()
# Out:
#     invoice_id  created_on  invoiceitem_id invoiceitem_name       type  \
# 291     301695  2019-04-26          103215        ii_103215      Other
# 289     301695  2019-04-26          166227        ii_166227  Equipment
# 292     301695  2019-04-26          171394        ii_171394      Other
# 290     301695  2019-04-26          195625        ii_195625      Other
# 129     304245  2019-03-17          121446        ii_121446    Service
#
#      unit_price  total_price  percentage_in_invoice  is_expired
# 291         135          945              37.485125       False
# 289         118          708              28.084094       False
# 292         128          128               5.077350       False
# 290         148          740              29.353431       False
# 129         158          632              12.842918       False

# %%
sorted_df.to_csv('C:\\Users\\Admin\\Desktop\\ServiceTitan\\invoices_dataset.csv', index=False)

# %% [markdown]
# ## Thank you :)
